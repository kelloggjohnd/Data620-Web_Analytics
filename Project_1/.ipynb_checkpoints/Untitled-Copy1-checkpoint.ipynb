# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('./global_terror_data_proj_1.csv')
df.head()
# Out:
#    iyear  imonth  iday         country_txt  \
# 0   1986       2    28              Sweden
# 1   1985       1     0  West Germany (FRG)
# 2   1985       1     0              France
# 3   1985       1     0              France
# 4   1985       1     0              France
#
#                                              summary  success  attacktype1  \
# 0  2/28/1986: Prime Minister Olof Palme was shot ...        1            2
# 1                                                NaN        0            3
# 2                                                NaN        1            9
# 3                                                NaN        1            9
# 4                                                NaN        1            9
#
#      attacktype1_txt              target1         targtype1_txt  claimed  \
# 0      Armed Assault           Olof Palme  Government (General)      1.0
# 1  Bombing/Explosion         Headquarters              Military      NaN
# 2            Unknown  Police Headquarters                Police      NaN
# 3            Unknown              unknown               Unknown      NaN
# 4            Unknown              unknown               Unknown      NaN
#
#      gname  weaptype1 weaptype1_txt  nkill
# 0  Unknown          5      Firearms    1.0
# 1  Unknown          6    Explosives    0.0
# 2  Unknown         13       Unknown    1.0
# 3  Unknown         13       Unknown    0.0
# 4  Unknown         13       Unknown    0.0

# %%
indexNames = df[df['gname'] == "Unknown"].index

# %%
ter_df = df[["country_txt", 'attacktype1']]
ter_df.head()
# Out:
#           country_txt  attacktype1
# 0              Sweden            2
# 1  West Germany (FRG)            3
# 2              France            9
# 3              France            9
# 4              France            9

# %%
catv = ter_df_sub.filter(["attacktype1"], axis=1)
catv['ID'] = catv.reset_index().index
catv.head()
# Out:
#       attacktype1  ID
# 1748            1   0
# 1776            3   1
# 2026            3   2
# 4150            1   3
# 4156            3   4

# %%
catv.head()
# Out:
#    attacktype1  ID
# 0            2   0
# 1            3   1
# 2            9   2
# 3            9   3
# 4            9   4

# %%
G=nx.from_pandas_dataframe(ter_df, 'country_txt', 'attacktype1', create_using=nx.Graph() )
#G.nodes()

# %%
catv= catv.set_index('ID')
catv=catv.reindex(G.nodes())

# %%
catv['attacktype1']=pd.Categorical(catv['attacktype1'])
catv['attacktype1'].cat.codes
# Out:
# ID
# Sweden               -1
# 2                     1
# West Germany (FRG)   -1
# 3                     0
# France               -1
#                      ..
# Turkmenistan         -1
# Serbia-Montenegro    -1
# Bhutan               -1
# Serbia               -1
# South Sudan          -1
# Length: 204, dtype: int8

# %%
plt.figure(figsize=(30,30))
nx.draw(G, with_labels=True, node_color=catv['attacktype1'].cat.codes, cmap=plt.cm.Set1, node_size=5, font_size=8)
plt.show()

# %%
ter_df_sub = ter_df[(ter_df.country_txt == "Iraq")|(ter_df.country_txt == "Turkey")|(ter_df.country_txt == "Syria")]
ter_df_sub['ID'] = np.arange(len(ter_df_sub))
# Out:
# C:\ProgramData\Anaconda3\envs\data620_web\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ter_df_sub.head(20)
# Out:
#      country_txt  attacktype1  ID
# 1748      Turkey            1   0
# 1776       Syria            3   1
# 2026      Turkey            3   2
# 4150       Syria            1   3
# 4156       Syria            3   4
# 4555       Syria            3   5
# 4999      Turkey            1   6
# 5011      Turkey            1   7
# 5025      Turkey            7   8
# 5043       Syria            3   9
# 5133      Turkey            1  10
# 5242      Turkey            2  11
# 5288      Turkey            1  12
# 5315      Turkey            3  13
# 5907      Turkey            9  14
# 5957      Turkey            3  15
# 5958      Turkey            3  16
# 6149      Turkey            2  17
# 6212      Turkey            6  18
# 6335      Turkey            3  19

# %%
catv = ter_df_sub.filter(["attacktype1"], axis=1)
catv['ID'] = catv.reset_index().index
catv.head()
# Out:
#       attacktype1  ID
# 1748            1   0
# 1776            3   1
# 2026            3   2
# 4150            1   3
# 4156            3   4

# %%
G=nx.from_pandas_dataframe(ter_df_sub, 'country_txt', 'attacktype1', create_using=nx.Graph() )
#G.nodes()

# %%
catv= catv.set_index('ID')
catv=catv.reindex(G.nodes())

# %%
catv['attacktype1']=pd.Categorical(catv['attacktype1'])
catv['attacktype1'].cat.codes
# Out:
# ID
# Turkey   -1
# 1         1
# Syria    -1
# 3         0
# 7         0
# 2         1
# 9         1
# 6         0
# Iraq     -1
# 5         1
# 8         2
# 4         1
# dtype: int8

# %%
plt.figure(figsize=(8,8))
nx.draw(G, with_labels=True, node_color=catv['attacktype1'].cat.codes, cmap=plt.cm.Set1, node_size=90, font_size=20)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-c2a012b3cce2> in <module>
#       1 ter_df_sub = ter_df[(ter_df.country_txt == "Iraq")|(ter_df.country_txt == "Turkey")|(ter_df.country_txt == "Syria")]
# ----> 2 ter_df_sub.drop(columns=['index'])
#       3 ter_df_sub['ID'] = np.arange(len(ter_df_sub))
#
# C:\ProgramData\Anaconda3\envs\data620_web\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4310             level=level,
#    4311             inplace=inplace,
# -> 4312             errors=errors,
#    4313         )
#    4314
#
# C:\ProgramData\Anaconda3\envs\data620_web\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4150         for axis, labels in axes.items():
#    4151             if labels is not None:
# -> 4152                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4153
#    4154         if inplace:
#
# C:\ProgramData\Anaconda3\envs\data620_web\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4185                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4186             else:
# -> 4187                 new_axis = axis.drop(labels, errors=errors)
#    4188             result = self.reindex(**{axis_name: new_axis})
#    4189
#
# C:\ProgramData\Anaconda3\envs\data620_web\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['index'] not found in axis"
