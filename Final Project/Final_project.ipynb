# %%
import nltk
import random
import pandas as pd
pd.set_option("display.max_rows",500)
import nltk.corpus
random.seed(42)
import numpy as np
from nltk.corpus import stopwords
nltk.download("stopwords")
from nltk.tokenize import word_tokenize
from nltk.corpus import PlaintextCorpusReader
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\x\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop_words = set(stopwords.words('english'))

# %%
corpus = pd.read_csv('data/corpus.csv')

# %%
corpus.head()
# Out:
#           Unnamed: 0                  Party  \
# 0  George Washington           Unaffiliated
# 1         John Adams             Federalist
# 2   Thomas Jefferson  Democratic-Republican
# 3      James Madison  Democratic-Republican
# 4       James Monroe  Democratic-Republican
#
#                                          transcripts
# 0  Fellow Citizens of the Senate and the House of...
# 1  When it was first perceived, in early times, t...
# 2  FRIENDS AND FELLOW-CITIZENS, Called upon to un...
# 3  Unwilling to depart from examples of the most ...
# 4  I should be destitute of feeling if I was not ...

# %%
speeches = pd.read_csv('data/presidential_speeches.csv')

# %%
speeches.head()
# Out:
#          Date          President         Party  \
# 0  1789-04-30  George Washington  Unaffiliated
# 1  1789-10-03  George Washington  Unaffiliated
# 2  1790-01-08  George Washington  Unaffiliated
# 3  1790-12-08  George Washington  Unaffiliated
# 4  1790-12-29  George Washington  Unaffiliated
#
#                                         Speech Title  \
# 0                            First Inaugural Address
# 1                          Thanksgiving Proclamation
# 2                   First Annual Message to Congress
# 3                  Second Annual Message to Congress
# 4  Talk to the Chiefs and Counselors of the Senec...
#
#                                              Summary  \
# 0  Washington calls on Congress to avoid local an...
# 1  At the request of Congress, Washington establi...
# 2  In a wide ranging speech, President Washington...
# 3  Washington focuses on commerce in his second a...
# 4  The President reassures the Seneca Nation that...
#
#                                           Transcript  \
# 0  Fellow Citizens of the Senate and the House of...
# 1  Whereas it is the duty of all Nations to ackno...
# 2  Fellow Citizens of the Senate and House of Rep...
# 3  Fellow citizens of the Senate and House of Rep...
# 4  I the President of the United States, by my ow...
#
#                                                  URL
# 0  https://millercenter.org/the-presidency/presid...
# 1  https://millercenter.org/the-presidency/presid...
# 2  https://millercenter.org/the-presidency/presid...
# 3  https://millercenter.org/the-presidency/presid...
# 4  https://millercenter.org/the-presidency/presid...

# %% [markdown]
# Import text from R script

# %%
ob=open('data/obama1.txt','rU')
raw_o=ob.read()
tokenizer = nltk.RegexpTokenizer(r"\w+")
obama = tokenizer.tokenize(raw_o)
# Out:
# C:\ProgramData\Anaconda3\envs\data620_web\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: 'U' mode is deprecated
#   """Entry point for launching an IPython kernel.

# %%
re=open('data/reagan.txt','rU')
raw_re=re.read()
tokenizer = nltk.RegexpTokenizer(r"\w+")
reagan = tokenizer.tokenize(raw_re)
# Out:
# C:\ProgramData\Anaconda3\envs\data620_web\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: 'U' mode is deprecated
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Update the text, remove stop words, lower case

# %%
obama = [word.lower() for word in obama if word.isalpha()]
reagan = [word.lower() for word in reagan if word.isalpha()]

# %%
obama_str = str(obama)
word_tokens = word_tokenize(obama_str)
tokens_without_sw = [w for w in word_tokens if not w in stop_words]
#tokens_without_sw = []        
obama_filtered = ("").join(tokens_without_sw)
obama_filtered = obama_filtered.replace(' , ', '')
obama_filtered = obama_filtered.replace(" ''", "")
obama_filtered = obama_filtered.replace("''", "")

# %%
len(obama_filtered)
# Out:
# 1521076

# %%
len(obama_filtered)/2000
# Out:
# 760.538

# %% [markdown]
# For ease of segmenting, I divided the length of the text by 2000 to get the amount of segments (1,101,169/2000 = ~550 Segments)

# %%
obama1=[]
for i in range(760):
    obama1.append([obama_filtered[i*2000:(i+1)*2000], 'ob'])

# %%
reagan = [word.lower() for word in reagan if word.isalpha()]
reagan_str = str(reagan)
word_tokens = word_tokenize(reagan_str)
tokens_without_sw = [w for w in word_tokens if not w in stop_words]
#tokens_without_sw = []        
reagan_filtered = ("").join(tokens_without_sw)
reagan_filtered = reagan_filtered.replace(' , ', '')
reagan_filtered = reagan_filtered.replace(" ''", "")
reagan_filtered = reagan_filtered.replace("''", "")

# %%
#reagan_filtered

# %%
len(reagan_filtered)/2000
# Out:
# 775.879

# %%
reagan1=[]
for i in range(775):
    reagan1.append([reagan_filtered[i*2000:(i+1)*2000], 're'])

# %% [markdown]
# ## Feature Extraction
#
# Creating the list of 1000 most frequent words

# %%
ro = obama+reagan
all_words = nltk.FreqDist(w.lower() for w in ro)
word_features = list(all_words)[:1000] #1000 most frequent words
wlist=[]
for i in range(0,1000,50):
    df=pd.DataFrame(word_features[i:(i+50)])
    df.columns=['50 words']
    wlist.append(df)   
pd.concat(wlist, axis=1)
# Out:
#    50 words    50 words  50 words  50 words    50 words        50 words  \
# 0       the          if     today        ll        past            look
# 1       and       world     right     still        keep       countries
# 2        to          re    should      then         end         already
# 3        of        been     going    better        done         program
# 4      that        when    united       too       being          reform
# 5         a  government       how        go    military       education
# 6        we       about      many    before       place          making
# 7        in       years       his      good      system          israel
# 8       our        just      said      same         got            arms
# 9         i        time       tax     never    national     opportunity
# 10      for       these       get       her       while         weapons
# 11       is        than    nation      very       women             law
# 12       it          no   freedom  children       lives         million
# 13        s    american     where     after     federal            bill
# 14     this         new     first       she         few             use
# 15      you       would      last      life      budget            live
# 16       be        them    future       day         job           thing
# 17     have     because   economy   tonight   something           stand
# 18       on        must       way     again        both       democracy
# 19     will        here       war      free       state        question
# 20      are          my   believe   history      energy            true
# 21       as        know      help  families        hard            high
# 22      not          he       don      each     without             off
# 23     with        some       own       ago        plan            tell
# 24      but        your       why   against      middle             yes
# 25     they        make      need     thank        ever           under
# 26      can        were  security    things     another           means
# 27   people          up     could      care      forces         defense
# 28      who         out      jobs     human      family          policy
# 29    their        well      made      part    progress           bring
# 30      all        work      most      hope    business             pay
# 31       by   president      even      next    citizens             ask
# 32        t     country      back   percent    continue            does
# 33       us         let       see    change    laughter          strong
# 34     more         had      down     young      around             act
# 35       so   americans  congress   nations     working           force
# 36     from        only  together    health    spending          across
# 37      was       every       say       may        such      leadership
# 38       or          me      much     union         man         leaders
# 39     what       peace      take   between     forward       political
# 40      has        over      come   support  businesses          months
# 41    there      states      into       god   important        millions
# 42      now         its        mr    rights      always            told
# 43       an       which     great      give        sure           small
# 44       ve        year    soviet       did       since           faith
# 45       at        like       any      home      growth     afghanistan
# 46       do        want  economic     power        once            fact
# 47  america       think   through       men         cut           taxes
# 48      one        also      long   nuclear        best           three
# 49    those       other       two       put   insurance  administration
#
#           50 words     50 words       50 words    50 words      50 words  \
# 0           allies          far        finally        four       poverty
# 1              yet          set          based  prosperity       schools
# 2           others         face         answer    recovery          hold
# 3             meet        point              q     courage     strategic
# 4             less     programs         second   democrats       society
# 5           office        begin           full       agree           oil
# 6             days         came          party     process          west
# 7             away      century           idea   inflation         needs
# 8           little          old          bless       ideas        longer
# 9          deficit       common        lebanon      toward         alone
# 10           clear         east            big     general       soviets
# 11            seen       course          given      become    everything
# 12      washington         real          sense        stop          goal
# 13           start         iraq         crisis      single          line
# 14           words     increase         living      public       parents
# 15         workers       spirit         fellow      threat         began
# 16          called         seek           love       folks       getting
# 17           build       action        college     special     beginning
# 18         whether        issue     commitment  individual         order
# 19             won    companies          earth      enough          turn
# 20            find         move           open       dream         fight
# 21           share         upon         school        self         makes
# 22        strength        child         higher       until        behind
# 23        problems   understand          built       asked       growing
# 24       ourselves      billion         debate   agreement       dignity
# 25  responsibility      members         during       reach         comes
# 26               d       europe        justice      reason   communities
# 27            didn    different          among        term         proud
# 28              am         half           talk  themselves          left
# 29           class  republicans        nothing       ahead          join
# 30           might       number         region   everybody           isn
# 31             him       nearly        dollars   including  negotiations
# 32         control      protect        provide        lost         major
# 33          effort      foreign           vote    politics          john
# 34        interest     possible         taking     instead          side
# 35           rates    secretary      financial      decade          iran
# 36          reduce         land           fair        kids      violence
# 37          values      friends  international          al        happen
# 38            kind         cuts          space      coming          pass
# 39           house       create         moment       story        trying
# 40           doing         lead          doesn    students      everyone
# 41          chance        cause       remember  challenges          week
# 42           money        speak         troops       trade       brought
# 43            took      problem          taken       costs       willing
# 44         promise      example        greater        ways        secure
# 45            able       within       missiles        cost     reduction
# 46           times       matter           feel    deficits          city
# 47      democratic      efforts     generation     private        income
# 48             lot       social         beyond      issues        passed
# 49       community         call        decades      almost         qaeda
#
#       50 words      50 words     50 words     50 words       50 words  \
# 0       worked         serve         gave      science           lose
# 1        raise       further     proposed        haven           rule
# 2   bipartisan         whole         cuba        court           role
# 3      central        ensure       really      address         return
# 4     policies          mean        rules     approach    individuals
# 5     election          laws        moral          air        reforms
# 6        leave         heart      purpose         mind         burden
# 7    thousands         civil    questions       record     experience
# 8        steps      campaign         hand         safe        however
# 9     building           age         race         path         afghan
# 10       basic     recognize       saying        black         report
# 11      simply        choose      parties         held           five
# 12    conflict       restore        night       places        learned
# 13     several       thought     actually          nor           easy
# 14  republican          task      mission       paying           sent
# 15  technology        remain         save      company         sector
# 16      global    revolution   strengthen     majority         indeed
# 17     liberty      proposal   principles      resolve  opportunities
# 18       whose          else       helped       invest           soon
# 19        rest        itself     peaceful      serious           sign
# 20     mondale  unemployment      achieve    neighbors         wanted
# 21       known       talking       dreams         wall          level
# 22     respect       someone        areas        vital       training
# 23       truth   generations         risk       having         attack
# 24   interests         equal  differences        cuban        hundred
# 25        used      greatest          led       pursue       tomorrow
# 26       found         heard       safety       result           wars
# 27       offer       message     happened  responsible    cooperation
# 28         saw         along       senate      savings           none
# 29       honor    confidence        woman    decisions          maybe
# 30        step       looking         hear       recent          takes
# 31      entire      medicare     benefits    increased           bush
# 32   necessary        market        south        range           ones
# 33    personal         month        weeks  development          tough
# 34        went          ours      ability    proposals          local
# 35         try         clean   difference    nicaragua           road
# 36        fear       certain        close       accept         anyone
# 37        debt        choice        lower      service          hopes
# 38   difficult       prevent         paid        solve           poor
# 39      simple         spend    resources          six         street
# 40    research      industry       ground          gas         regard
# 41   sometimes          rate      helping        spent    legislation
# 42      afford       meeting      actions       though           area
# 43     created        fought       agenda   throughout           knew
# 44         met       success          top        works           play
# 45       often         white   especially        wrong        deserve
# 46      treaty         trust     anything    recession        destiny
# 47       third   governments   investment         says       struggle
# 48        send      stronger         deal     coverage     ultimately
# 49        grow     challenge      present       rather          group
#
#          50 words          50 words       50 words      50 words
# 0           least            hearts         summit          gone
# 1           facts             focus        attacks        regime
# 2          asking        reductions     determined        reagan
# 3           final         gorbachev           asia       reduced
# 4          geneva           measure      sacrifice         bills
# 5        evidence           student            win      veterans
# 6            born        innovation        require          fall
# 7        standing        terrorists   independence        mutual
# 8          giving             grace          above     terrorist
# 9             bad          decision       founding           era
# 10         defend            couldn        peoples         globe
# 11         person           elected       consider         price
# 12          spoke           lasting    information        groups
# 13          later             north        highest         pride
# 14         needed          prepared      encourage       perhaps
# 15         father            either         killed        combat
# 16       fighting              show        changes       marines
# 17        speaker           western           duty     situation
# 18        improve           started    investments            ii
# 19      potential              nato     industries      position
# 20         africa                ms         mother       journey
# 21       somebody           senator          break       kennedy
# 22          talks            served         voices      teachers
# 23         thanks             worst          knows         hours
# 24          homes        transition           read     eliminate
# 25         credit        assistance           stay      powerful
# 26         george         committed  congressional        expand
# 27          hands      palestinians         moving       tragedy
# 28          terms        initiative           aren          deep
# 29           sick             doubt        develop   competition
# 30           wage           threats          table      maintain
# 31       strategy          believed            key  conventional
# 32          shall             carry   institutions        harder
# 33  determination          capacity      religious         china
# 34         ideals           changed    palestinian          army
# 35          goals          complete           drug     standards
# 36      essential      constitution            low      religion
# 37          allow          hundreds          armed      balanced
# 38        markets  responsibilities       whatever     stability
# 39         period            abroad    fundamental         nancy
# 40        allowed             truly         turned     authority
# 41           case               run          early       shouldn
# 42           vice            expect       reducing    commission
# 43         belief             gives    immigration        church
# 44          ready            berlin          lived        skills
# 45         follow             begun        largest       grenada
# 46         leader          critical          waste      historic
# 47          short           housing           view       farmers
# 48        remains       regulations         agreed       failure
# 49        borders             learn         levels        broken

# %% [markdown]
# From text book

# %%
def document_features(document): 
    document_words = set(document) 
    features = {}
    for word in word_features:
        features['contains({})'.format(word)] = (word in document_words)
    return features

# %% [markdown]
# run features on Washington's speeches

# %%
features = document_features(reagan)
list(features.items())[10:30]
# Out:
# [('contains(for)', True),
#  ('contains(is)', True),
#  ('contains(it)', True),
#  ('contains(s)', True),
#  ('contains(this)', True),
#  ('contains(you)', True),
#  ('contains(be)', True),
#  ('contains(have)', True),
#  ('contains(on)', True),
#  ('contains(will)', True),
#  ('contains(are)', True),
#  ('contains(as)', True),
#  ('contains(not)', True),
#  ('contains(with)', True),
#  ('contains(but)', True),
#  ('contains(they)', True),
#  ('contains(can)', True),
#  ('contains(people)', True),
#  ('contains(who)', True),
#  ('contains(their)', True)]

# %% [markdown]
# ## Test/Train Dataset

# %%
speeches = obama1+reagan1

# %%
# Out:
# 1535

# %%
import random
random.shuffle(speeches)
featuresets = [(document_features(d), c) for (d,c) in speeches]
len(featuresets)
# Out:
# 1535

# %%
train_set, test_set = featuresets[:1000], featuresets[1000:]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.5327102803738317

# %% [markdown]
# 53% - not great
#
# Does it get better or worse if we add in another speaker.

# %% [markdown]
# ### Adding Roosevelt

# %%
ro=open('data/roosevelt.txt','rU')
raw_r=ro.read()
tokens_r = nltk.word_tokenize(raw_r)
roosevelt = nltk.Text(tokens_r)
roosevelt = [word.lower() for word in roosevelt if word.isalpha()]
roosevelt_str = str(roosevelt)
word_tokens = word_tokenize(roosevelt_str)
tokens_without_sw = [w for w in word_tokens if not w in stop_words]
#tokens_without_sw = []        
roosevelt_filtered = (" ").join(tokens_without_sw)
roosevelt_filtered = roosevelt_filtered.replace(' , ', '')
roosevelt_filtered = roosevelt_filtered.replace(" ''", " ")

len(roosevelt_filtered)
# Out:
# C:\ProgramData\Anaconda3\envs\data620_web\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: 'U' mode is deprecated
#   """Entry point for launching an IPython kernel.
# 731932

# %%
roosevelt1=[]
for i in range(242):
    roosevelt1.append([roosevelt_filtered[i*2000:(i+1)*2000], 'ro'])

# %%
orr = obama+reagan+roosevelt
all_words = nltk.FreqDist(w.lower() for w in orr)
word_features = list(all_words)[:200] #200 most frequent words

speeches = obama1+reagan1+roosevelt1

# %%
random.shuffle(speeches)
featuresets = [(document_features(d), c) for (d,c) in speeches]
len(featuresets)
# Out:
# 1777

# %%
train_set, test_set = featuresets[:100], featuresets[100:]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.43351222420989866

# %% [raw]
# words words

# %% [markdown]
# ## Kennedy

# %%
ke=open('data/kennedy.txt','rU')
raw_k=ke.read()
tokens_k = nltk.word_tokenize(raw_k)
kennedy = nltk.Text(tokens_k)
kennedy = [word.lower() for word in kennedy if word.isalpha()]
kennedy_str = str(kennedy)
word_tokens = word_tokenize(kennedy_str)
tokens_without_sw = [w for w in word_tokens if not w in stop_words]
#tokens_without_sw = []        
kennedy_filtered = (" ").join(tokens_without_sw)
kennedy_filtered = kennedy_filtered.replace(' , ', '')
kennedy_filtered = kennedy_filtered.replace(" ''", " ")

len(kennedy_filtered)/2000
# Out:
# C:\ProgramData\Anaconda3\envs\data620_web\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: 'U' mode is deprecated
#   """Entry point for launching an IPython kernel.
# 336.1905

# %%
kennedy1=[]
for i in range(242):
    kennedy1.append([kennedy_filtered[i*2000:(i+1)*2000], 'ke'])

# %%
orrk = obama+reagan+roosevelt+kennedy
all_words = nltk.FreqDist(w.lower() for w in orrk)
word_features = list(all_words)[:200] #200 most frequent words

speeches = obama1+reagan1+roosevelt1+kennedy1

# %%
random.shuffle(speeches)
featuresets = [(document_features(d), c) for (d,c) in speeches]
len(featuresets)
# Out:
# 2019

# %%
train_set, test_set = featuresets[:100], featuresets[100:]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.3830119854090672

# %% [markdown]
# words words

# %% [markdown]
# ## Clinton

# %%
cl=open('data/clinton.txt','rU')
raw_c=cl.read()
tokens_c = nltk.word_tokenize(raw_c)
clinton = nltk.Text(tokens_c)
clinton = [word.lower() for word in clinton if word.isalpha()]
clinton_str = str(clinton)
word_tokens = word_tokenize(clinton_str)
tokens_without_sw = [w for w in word_tokens if not w in stop_words]
#tokens_without_sw = []        
clinton_filtered = (" ").join(tokens_without_sw)
clinton_filtered = clinton_filtered.replace(' , ', '')
clinton_filtered = clinton_filtered.replace(" ''", " ")

len(clinton_filtered)/2000
# Out:
# C:\ProgramData\Anaconda3\envs\data620_web\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: 'U' mode is deprecated
#   """Entry point for launching an IPython kernel.
# 367.9435

# %%
clinton1=[]
for i in range(367):
    clinton1.append([clinton_filtered[i*2000:(i+1)*2000], 'cl'])

# %%
orrkc = obama+reagan+roosevelt+kennedy+clinton
all_words = nltk.FreqDist(w.lower() for w in orrkc)
word_features = list(all_words)[:200] #200 most frequent words

speeches = obama1+reagan1+roosevelt1+kennedy1+clinton1

# %%
random.shuffle(speeches)
featuresets = [(document_features(d), c) for (d,c) in speeches]
len(featuresets)
# Out:
# 2386

# %%
train_set, test_set = featuresets[:100], featuresets[100:]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.32458442694663164

# %% [markdown]
# words words

# %%
classifier.show_most_informative_features(40)
# Out:
# Most Informative Features
#              contains(a) = True               cl : ro     =      1.0 : 1.0
#          contains(about) = False              cl : ro     =      1.0 : 1.0
#          contains(after) = False              cl : ro     =      1.0 : 1.0
#          contains(again) = False              cl : ro     =      1.0 : 1.0
#        contains(against) = False              cl : ro     =      1.0 : 1.0
#            contains(ago) = False              cl : ro     =      1.0 : 1.0
#            contains(all) = False              cl : ro     =      1.0 : 1.0
#           contains(also) = False              cl : ro     =      1.0 : 1.0
#             contains(am) = False              cl : ro     =      1.0 : 1.0
#        contains(america) = False              cl : ro     =      1.0 : 1.0
#       contains(american) = False              cl : ro     =      1.0 : 1.0
#      contains(americans) = False              cl : ro     =      1.0 : 1.0
#             contains(an) = False              cl : ro     =      1.0 : 1.0
#            contains(and) = False              cl : ro     =      1.0 : 1.0
#            contains(any) = False              cl : ro     =      1.0 : 1.0
#            contains(are) = False              cl : ro     =      1.0 : 1.0
#             contains(as) = False              cl : ro     =      1.0 : 1.0
#             contains(at) = False              cl : ro     =      1.0 : 1.0
#           contains(back) = False              cl : ro     =      1.0 : 1.0
#             contains(be) = False              cl : ro     =      1.0 : 1.0
#        contains(because) = False              cl : ro     =      1.0 : 1.0
#           contains(been) = False              cl : ro     =      1.0 : 1.0
#         contains(before) = False              cl : ro     =      1.0 : 1.0
#        contains(believe) = False              cl : ro     =      1.0 : 1.0
#         contains(better) = False              cl : ro     =      1.0 : 1.0
#        contains(between) = False              cl : ro     =      1.0 : 1.0
#           contains(both) = False              cl : ro     =      1.0 : 1.0
#            contains(but) = False              cl : ro     =      1.0 : 1.0
#             contains(by) = False              cl : ro     =      1.0 : 1.0
#            contains(can) = False              cl : ro     =      1.0 : 1.0
#           contains(care) = False              cl : ro     =      1.0 : 1.0
#       contains(children) = False              cl : ro     =      1.0 : 1.0
#           contains(come) = False              cl : ro     =      1.0 : 1.0
#       contains(congress) = False              cl : ro     =      1.0 : 1.0
#          contains(could) = False              cl : ro     =      1.0 : 1.0
#        contains(country) = False              cl : ro     =      1.0 : 1.0
#            contains(day) = False              cl : ro     =      1.0 : 1.0
#            contains(did) = False              cl : ro     =      1.0 : 1.0
#             contains(do) = False              cl : ro     =      1.0 : 1.0
#           contains(down) = False              cl : ro     =      1.0 : 1.0
