# %%
import nltk
import random
import pandas as pd
pd.set_option("display.max_rows",500)
import nltk.corpus
random.seed(42)
import numpy as np
from nltk.corpus import stopwords
nltk.download("stopwords")
from nltk.tokenize import word_tokenize
from nltk.corpus import PlaintextCorpusReader
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\x\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# https://www.huffpost.com/entry/obama-is-americas-3rd-gre_b_813868
#
# Can we use text mining to predict the speeches of the top Presidential Orators since 1933?
# What are their commonalities?

# %%
stop_words = set(stopwords.words('english'))

# %%
corpus = pd.read_csv('data/corpus.csv')

# %%
corpus.head()

# %%
speeches = pd.read_csv('data/presidential_speeches.csv')

# %%
speeches.head()

# %% [markdown]
# Import text from R script

# %%
ob=open('data/obama1.txt','rU')
raw_o=ob.read()
tokenizer = nltk.RegexpTokenizer(r"\w+")
obama = tokenizer.tokenize(raw_o)
# Out:
# C:\ProgramData\Anaconda3\envs\data620_web\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: 'U' mode is deprecated
#   """Entry point for launching an IPython kernel.

# %%
wa=open('data/washington.txt','rU')
raw_w=wa.read()
tokenizer = nltk.RegexpTokenizer(r"\w+")
washington = tokenizer.tokenize(raw_w)
# Out:
# C:\ProgramData\Anaconda3\envs\data620_web\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: 'U' mode is deprecated
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Update the text, remove stop words, lower case

# %%
obama = [word.lower() for word in obama if word.isalpha()]

# %%
obama_str = str(obama)
obama = word_tokenize(obama_str)
#tokens_without_sw = [w for w in word_tokens if not w in stop_words]
#obama_filtered = ("").join(tokens_without_sw)

# %%
tokens_without_sw

# %%
#tokens_without_sw = []        
#obama_filtered = ("").join(tokens_without_sw)
obama_filtered = obama.replace(' , ', '')
obama_filtered = obama_filtered.replace(" ''", "")
obama_filtered = obama_filtered.replace("''", "")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-85dc93392239> in <module>
#       1 #tokens_without_sw = []
#       2 #obama_filtered = ("").join(tokens_without_sw)
# ----> 3 obama_filtered = obama.replace(' , ', '')
#       4 obama_filtered = obama_filtered.replace(" ''", "")
#       5 obama_filtered = obama_filtered.replace("''", "")
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
len(obama)
# Out:
# 628420

# %%
len(obama)/2000
# Out:
# 314.21

# %% [markdown]
# For ease of segmenting, I divided the length of the text by 2000 to get the amount of segments (1,101,169/2000 = ~550 Segments)

# %%
obama1=[]
for i in range(314):
    obama1.append([obama[i*2000:(i+1)*2000], 'ob'])

# %%
washington = [word.lower() for word in washington if word.isalpha()]
washington_str = str(washington)
washington = word_tokenize(washington_str)
#tokens_without_sw = [w for w in word_tokens if not w in stop_words]
#tokens_without_sw = []        
#washington_filtered = ("").join(tokens_without_sw)
#washington_filtered = washington.replace(' , ', '')
#washington_filtered = washington_filtered.replace(" ''", "")
#washington_filtered = washington_filtered.replace("''", "")

# %%
len(washington)/2000
# Out:
# 47.627

# %%
washington1=[]
for i in range(47):
    washington1.append([washington[i*2000:(i+1)*2000], 'wa'])

# %% [markdown]
# ## Feature Extraction
#
# Creating the list of 1000 most frequent words

# %%
wo = obama+washington
all_words = nltk.FreqDist(w.lower() for w in wo)
word_features = list(all_words)[:1000] #1000 most frequent words
wlist=[]
for i in range(0,1000,50):
    df=pd.DataFrame(word_features[i:(i+50)])
    df.columns=['50 words']
    wlist.append(df)   
pd.concat(wlist, axis=1)
# Out:
#     50 words     50 words    50 words     50 words      50 words  \
# 0          '         'was      'where         'see         'then
# 1          ,       'those    'economy        'said          'end
# 2       'the        'been       'need      'change      'support
# 3       'and        'just        'why       'peace       'public
# 4        'to         'one        'its  'businesses          'men
# 5        'of        'when      'other        'much       'reform
# 6      'that       'these         'he       'could    'education
# 7          a       'which       'year        'give         'very
# 8        'we          're        'may      'energy      'history
# 9        'in     'because       'many        'same      'working
# 10      'our       'about        'his          'll        'state
# 11      'for        'them      'think        'part       'making
# 12       'is         'new        'don   'insurance      'between
# 13         i          'my     'future         'got         'each
# 14       'it        'make        'own        'next         'both
# 15        's        'your       'only     'against      'workers
# 16       'be        'here       'care        'down      'forward
# 17     'this        'time        'war    'children          'act
# 18     'have        'than   'security        'home        'class
# 19      'you        'some       'even         'job    'companies
# 20     'will       'world        'way      'before         'such
# 21      'are     'country       'made       'great       'around
# 22       'on    'american     'health     'tonight        'lives
# 23      'not      'states       'good      'system     'progress
# 24     'with       'every       'most          'go         'iraq
# 25       'as        'know       'last         'tax         'best
# 26      'can          'no       'well       'power    'important
# 27      'but        'work      'today    'citizens      'already
# 28     'they       'years       'help        'plan         'hope
# 29      'who      'united        'she       'thank        'small
# 30       'by          'up   'congress         'day          'did
# 31    'their       'right    'believe        'keep  'opportunity
# 32     'more       'would      'first     'without          'god
# 33   'people         'out       'take        'hard         'upon
# 34       'or      'should       'into       'while       'always
# 35        't        'must   'together    'business         'life
# 36     'from   'americans       'back         'put         'look
# 37       'so  'government        'her     'nations         'true
# 38      'all        'like        'any        'sure        'means
# 39     'what        'want        'had       'young         'past
# 40      'has         'how   'families       'women          'pay
# 41       'us        'jobs    'through      'things     'laughter
# 42       'an        'also     'better         'law  'afghanistan
# 43       'do         'get        'too         'say        'human
# 44       've        'over       'come       'never        'thing
# 45       'at         'let  'president       'being       'israel
# 46  'america          'me      'still      'middle          'lot
# 47      'now        'were        'two        'done          'ago
# 48    'there      'nation       'long      'rights    'something
# 49       'if       'going      'after       'place  'republicans
#
#            50 words     50 words      50 words         50 words  \
# 0          'another    'national          'oil             'him
# 1              'few   'everybody   'leadership         'provide
# 2         'continue        'idea          'far           'clean
# 3           'across   'democracy         'full          'higher
# 4             'free        'ever       'nearly           'built
# 5         'millions         'won        'union            'days
# 6            'since      'months        'doesn           'times
# 7           'family       'doing   'understand           'makes
# 8        'community        'away      'decades        'students
# 9            'house   'different         'find            'tell
# 10        'military       'money        'bring          'spirit
# 11            'high      'create          'man             'old
# 12         'leaders      'crisis     'possible            'stop
# 13           'under     'deficit     'interest            'cost
# 14            'meet       'sense       'school            'didn
# 15       'countries     'million      'finally          'enough
# 16         'promise        'face     'violence            'talk
# 17            'bill  'challenges         'cuts         'schools
# 18             'off       'qaeda       'debate            'term
# 19      'washington       'agree    'political          'policy
# 20           'build         'yet            'd           'words
# 21           'again     'justice         'debt            'fair
# 22          'common        'seen     'question           'space
# 23           'folks       'might        'force         'willing
# 24           'stand      'course      'efforts           'comes
# 25            'less    'politics       'growth            'came
# 26         'college   'democrats      'example         'growing
# 27            'able     'century  'communities      'republican
# 28           'clear         'big       'single         'respect
# 29        'economic       'child         'move         'instead
# 30  'responsibility     'protect        'faith      'everything
# 31            'does         'cut         'lost          'global
# 32         'whether      'effort       'values         'members
# 33       'financial      'strong       'reason         'success
# 34            'live       'shall        'point  'administration
# 35            'kids       'share          'ask          'happen
# 36            'laws        'vote        'three          'issues
# 37          'troops       'costs         'kind          'fellow
# 38              'al        'fact        'rules          'worked
# 39             'set  'prosperity         'took         'nothing
# 40           'issue   'ourselves        'speak          'little
# 41          'office        'love       'region        'strength
# 42              'am  'generation        'party         'dignity
# 43          'within      'afford      'foreign           'given
# 44          'chance     'freedom        'bless            'real
# 45         'percent       'ideas       'action          'allies
# 46           'start        'open         'pass          'number
# 47            'lead      'others       'forces          'decade
# 48            'once     'nuclear       'matter         'prevent
# 49             'use   'necessary        'reach         'problem
#
#           50 words      50 words       50 words      50 words  \
# 0           'taken        'begin       'deserve     'stronger
# 1       'interests        'often    'democratic        'honor
# 2           'story      'general          'fear       'helped
# 3            'ways       'afghan         'works     'recovery
# 4      'themselves         'told         'steps        'north
# 5            'grow        'equal       'looking       'having
# 6           'earth        'alone         'needs         'five
# 7         'parties       'choice       'program        'tough
# 8          'secure       'coming         'offer  'investments
# 9       'sometimes         'path      'benefits        'dream
# 10         'market       'during       'society        'white
# 11         'passed         'race          'goal           'mr
# 12    'generations    'thousands           'gas     'approach
# 13     'commitment      'company          'save     'somebody
# 14        'weapons      'courage          'seek        'woman
# 15        'friends      'process        'street        'south
# 16           'half     'industry        'trying         'side
# 17         'senate        'order  'constitution       'fought
# 18          'known      'present          'else         'turn
# 19         'moment      'poverty           'six    'resources
# 20           'john     'election       'liberty         'easy
# 21           'call      'science      'research        'grace
# 22     'technology   'confidence          'hear        'trust
# 23          'ahead  'information       'created   'transition
# 24         'budget     'medicare         'serve       'simply
# 25            'yes         'feel          'lose     'conflict
# 26          'fight         'four         'along       'ground
# 27        'greater       'credit           'isn        'civil
# 28         'taking        'truth         'basic       'paying
# 29       'everyone       'living         'until       'entire
# 30        'dollars     'problems         'leave      'address
# 31        'getting        'taxes          'send         'cuba
# 32          'among        'cause          'safe         'sick
# 33         'invest        'trade          'line     'remember
# 34       'coverage   'principles          'self      'federal
# 35         'choose        'based        'though     'programs
# 36       'spending       'behind       'further          'bad
# 37      'recognize     'building           'nor        'whose
# 38  'international   'experience          'step    'decisions
# 39         'beyond      'service       'helping       'simple
# 40          'raise       'pursue           'top    'beginning
# 41        'certain       'longer         'focus        'allow
# 42         'called   'innovation        'ensure        'least
# 43        'parents      'require      'actually         'used
# 44           'iran          'led          'mean   'particular
# 45         'second       'reduce          'paid   'especially
# 46      'difficult      'private       'serious         'land
# 47          'whole             q           'try        'month
# 48      'including        'found          'hand        'solve
# 49           'hold         'week    'strengthen         'wage
#
#             50 words      50 words           50 words        50 words  \
# 0            'person        'gives          'veterans        'changes
# 1       'immigration          'met             'hands         'skills
# 2             'haven      'towards            'social       'ordinary
# 3            'places   'ultimately          'tomorrow         'really
# 4        'bipartisan        'court            'rather  'opportunities
# 5          'whatever         'rest           'defense         'defend
# 6        'individual      'reforms              'stay     'throughout
# 7         'recession    'situation         'challenge        'muslims
# 8           'student        'ought           'largest         'muslim
# 9        'investment       'dreams           'attacks      'essential
# 10           'abroad     'teachers              'case        'chamber
# 11          'purpose       'harder            'belief      'potential
# 12            'heard        'third             'terms           'hire
# 13             'wall         'duty            'income         'access
# 14           'remain         'east              'play         'combat
# 15            'spend        'close         'influence   'particularly
# 16      'governments   'affordable             'lower       'proposal
# 17          'markets      'mission               'bin         'proper
# 18     'palestinians   'immigrants             'laden         'accept
# 19  'representatives      'subject             'weeks       'starting
# 20           'become     'capacity          'campaign           'fall
# 21              'gun      'control           'thought      'standards
# 22           'expect      'borders             'worst     'industries
# 23           'answer       'saying          'commerce     'terrorists
# 24           'itself     'happened              'sign        'climate
# 25          'ability     'increase              'none            'run
# 26           'safety        'asked           'actions          'voice
# 27         'pakistan        'parts          'trillion        'savings
# 28         'israelis       'europe              'aren            'age
# 29            'cuban        'takes     'comprehensive      'happiness
# 30          'achieve         'mind          'training           'rule
# 31            'doubt       'result         'agreement           'soon
# 32              'saw   'retirement         'attention          'globe
# 33             'risk   'difference            'powers         'danger
# 34             'laid      'measure     'manufacturing        'elected
# 35      'differences        'local        'inequality        'lasting
# 36        'questions  'responsible             'china         'agenda
# 37             'wars       'giving           'brought          'facts
# 38             'deal       'served  'responsibilities           'gave
# 39         'majority        'wages               'lay       'peaceful
# 40      'individuals        'spent           'threats         'killed
# 41          'several     'greatest          'strategy        'shouldn
# 42            'rates         'sent            'ideals         'friend
# 43           'treaty        'began            'threat         'thanks
# 44         'measures         'task           'improve           'cars
# 45          'talking     'colleges             'banks       'anything
# 46         'deficits    'authority     'circumstances           'ones
# 47             'west  'development       'palestinian            'fix
# 48             'left        'proud          'requires        'compete
# 49             'join        'homes            'africa       'premiums
#
#           50 words       50 words        50 words
# 0           'iraqi          'code     'friendship
# 1         'taliban       'billion     'protection
# 2          'anyone        'mutual        'minimum
# 3       'neighbors        'follow       'grateful
# 4        'powerful       'choices      'sacrifice
# 5   'determination      'believed        'streets
# 6            'held      'governor          'ready
# 7          'expand         'heart           'knew
# 8            'role         'later        'someone
# 9           'areas         'knows           'ours
# 10            'buy       'promote        'natural
# 11         'either          'fail        'knowing
# 12        'succeed    'foundation        'hopeful
# 13   'institutions        'father         'rising
# 14        'meeting         'wrong         'needed
# 15          'assad         'shape         'effect
# 16        'journey     'secretary        'changed
# 17         'shared  'unemployment       'consider
# 18           'went     'executive        'depends
# 19         'easier     'committed         'source
# 20          'wants        'hearts       'religion
# 21        'restore       'however            'hit
# 22      'character          'rate       'officers
# 23        'message     'provision  'entrepreneurs
# 24        'perfect    'additional         'depend
# 25           'earn          'city        'perhaps
# 26        'remains          'eyes          'large
# 27       'fighting      'hundreds        'seniors
# 28         'denied        'earned  'extraordinary
# 29        'special           'win         'almost
# 30         'moving          'says          'lands
# 31      'encourage        'mother   'construction
# 32         'asking     'diplomacy         'nature
# 33         'burden        'demand        'conduct
# 34           'acts   'accountable           'nasa
# 35    'competition         'break      'execution
# 36        'session          'arms        'militia
# 37         'regime         'aside          'train
# 38       'products        'former           'news
# 39      'therefore        'return         'mccain
# 40        'indians      'applause          'chief
# 41          'night       'medical       'standing
# 42          'bills         'level      'providing
# 43         'broken   'legislation        'learned
# 44       'policies         'learn      'terrorist
# 45        'senator         'maybe           'walk
# 46           'born       'resolve       'decision
# 47        'receive      'proposed         'voices
# 48          'loans           'add       'struggle
# 49           'road       'allowed    'cooperation

# %% [markdown]
# From text book

# %%
def document_features(document): 
    document_words = set(document) 
    features = {}
    for word in word_features:
        features['contains({})'.format(word)] = (word in document_words)
    return features

# %% [markdown]
# run features on Washington's speeches

# %%
features = document_features(washington)
list(features.items())[10:30]
# Out:
# [("contains('our)", True),
#  ("contains('for)", True),
#  ("contains('is)", True),
#  ('contains(i)', True),
#  ("contains('it)", True),
#  ("contains('s)", True),
#  ("contains('be)", True),
#  ("contains('this)", True),
#  ("contains('have)", True),
#  ("contains('you)", True),
#  ("contains('will)", True),
#  ("contains('are)", True),
#  ("contains('on)", True),
#  ("contains('not)", True),
#  ("contains('with)", True),
#  ("contains('as)", True),
#  ("contains('can)", True),
#  ("contains('but)", True),
#  ("contains('they)", True),
#  ("contains('who)", True)]

# %% [markdown]
# ## Test/Train Dataset

# %%
speeches = obama1+washington1

# %%
import random
random.shuffle(speeches)
featuresets = [(document_features(d), c) for (d,c) in speeches]
len(featuresets)
# Out:
# 361

# %%
train_set, test_set = featuresets[:1000], featuresets[1000:]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0

# %% [markdown]
# 53% - not great
#
# Does it get better or worse if we add in another speaker.

# %% [markdown]
# ## Model Reset

# %%
re=open('data/reagan.txt','rU')
raw_re=re.read()
tokenizer = nltk.RegexpTokenizer(r"\w+")
reagan = tokenizer.tokenize(raw_re)

# %%
reagan = [word.lower() for word in reagan if word.isalpha()]
reagan = [word.lower() for word in reagan if word.isalpha()]
reagan_str = str(reagan)
word_tokens = word_tokenize(reagan_str)
tokens_without_sw = [w for w in word_tokens if not w in stop_words]
#tokens_without_sw = []        
reagan_filtered = ("").join(tokens_without_sw)
reagan_filtered = reagan_filtered.replace(' , ', '')
reagan_filtered = reagan_filtered.replace(" ''", "")
reagan_filtered = reagan_filtered.replace("''", "")

# %%
len(reagan_filtered)/2000

# %%
reagan1=[]
for i in range(775):
    reagan1.append([reagan_filtered[i*2000:(i+1)*2000], 're'])

# %%
ro = obama+reagan
all_words = nltk.FreqDist(w.lower() for w in ro)
word_features = list(all_words)[:1000] #1000 most frequent words
wlist=[]
for i in range(0,1000,50):
    df=pd.DataFrame(word_features[i:(i+50)])
    df.columns=['50 words']
    wlist.append(df)   
pd.concat(wlist, axis=1)

# %% [markdown]
# ### Adding Roosevelt

# %%
ro=open('data/roosevelt.txt','rU')
raw_r=ro.read()
tokens_r = nltk.word_tokenize(raw_r)
roosevelt = nltk.Text(tokens_r)
roosevelt = [word.lower() for word in roosevelt if word.isalpha()]
roosevelt_str = str(roosevelt)
word_tokens = word_tokenize(roosevelt_str)
tokens_without_sw = [w for w in word_tokens if not w in stop_words]
#tokens_without_sw = []        
roosevelt_filtered = (" ").join(tokens_without_sw)
roosevelt_filtered = roosevelt_filtered.replace(' , ', '')
roosevelt_filtered = roosevelt_filtered.replace(" ''", " ")

len(roosevelt_filtered)

# %%
roosevelt1=[]
for i in range(242):
    roosevelt1.append([roosevelt_filtered[i*2000:(i+1)*2000], 'ro'])

# %%
orr = obama+reagan+roosevelt
all_words = nltk.FreqDist(w.lower() for w in orr)
word_features = list(all_words)[:200] #200 most frequent words

speeches = obama1+reagan1+roosevelt1

# %%
random.shuffle(speeches)
featuresets = [(document_features(d), c) for (d,c) in speeches]
len(featuresets)

# %%
train_set, test_set = featuresets[:100], featuresets[100:]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))

# %% [raw]
# words words

# %% [markdown]
# ## Kennedy

# %%
ke=open('data/kennedy.txt','rU')
raw_k=ke.read()
tokens_k = nltk.word_tokenize(raw_k)
kennedy = nltk.Text(tokens_k)
kennedy = [word.lower() for word in kennedy if word.isalpha()]
kennedy_str = str(kennedy)
word_tokens = word_tokenize(kennedy_str)
tokens_without_sw = [w for w in word_tokens if not w in stop_words]
#tokens_without_sw = []        
kennedy_filtered = (" ").join(tokens_without_sw)
kennedy_filtered = kennedy_filtered.replace(' , ', '')
kennedy_filtered = kennedy_filtered.replace(" ''", " ")

len(kennedy_filtered)/2000

# %%
kennedy1=[]
for i in range(242):
    kennedy1.append([kennedy_filtered[i*2000:(i+1)*2000], 'ke'])

# %%
orrk = obama+reagan+roosevelt+kennedy
all_words = nltk.FreqDist(w.lower() for w in orrk)
word_features = list(all_words)[:200] #200 most frequent words

speeches = obama1+reagan1+roosevelt1+kennedy1

# %%
random.shuffle(speeches)
featuresets = [(document_features(d), c) for (d,c) in speeches]
len(featuresets)

# %%
train_set, test_set = featuresets[:100], featuresets[100:]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))

# %% [markdown]
# words words

# %% [markdown]
# ## Clinton

# %%
cl=open('data/clinton.txt','rU')
raw_c=cl.read()
tokens_c = nltk.word_tokenize(raw_c)
clinton = nltk.Text(tokens_c)
clinton = [word.lower() for word in clinton if word.isalpha()]
clinton_str = str(clinton)
word_tokens = word_tokenize(clinton_str)
tokens_without_sw = [w for w in word_tokens if not w in stop_words]
#tokens_without_sw = []        
clinton_filtered = (" ").join(tokens_without_sw)
clinton_filtered = clinton_filtered.replace(' , ', '')
clinton_filtered = clinton_filtered.replace(" ''", " ")

len(clinton_filtered)/2000

# %%
clinton1=[]
for i in range(367):
    clinton1.append([clinton_filtered[i*2000:(i+1)*2000], 'cl'])

# %%
orrkc = obama+reagan+roosevelt+kennedy+clinton
all_words = nltk.FreqDist(w.lower() for w in orrkc)
word_features = list(all_words)[:200] #200 most frequent words

speeches = obama1+reagan1+roosevelt1+kennedy1+clinton1

# %%
random.shuffle(speeches)
featuresets = [(document_features(d), c) for (d,c) in speeches]
len(featuresets)

# %%
train_set, test_set = featuresets[:100], featuresets[100:]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))

# %% [markdown]
# words words

# %%
classifier.show_most_informative_features(40)
