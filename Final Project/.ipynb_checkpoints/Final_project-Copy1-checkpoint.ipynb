# %%
import nltk
import random
import pandas as pd
pd.set_option("display.max_rows",500)
import nltk.corpus
random.seed(42)
import numpy as np
from nltk.corpus import stopwords
nltk.download("stopwords")
from nltk.tokenize import word_tokenize
from nltk.corpus import PlaintextCorpusReader

#warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\x\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# https://www.huffpost.com/entry/obama-is-americas-3rd-gre_b_813868
#
# Can we use text mining to predict the speeches of the top Presidential Orators since 1933?
# What are their commonalities?

# %%
stop_words = set(stopwords.words('english'))

# %%
corpus = pd.read_csv('data/corpus.csv')

# %%
corpus.head()
# Out:
#           Unnamed: 0                  Party  \
# 0  George Washington           Unaffiliated
# 1         John Adams             Federalist
# 2   Thomas Jefferson  Democratic-Republican
# 3      James Madison  Democratic-Republican
# 4       James Monroe  Democratic-Republican
#
#                                          transcripts
# 0  Fellow Citizens of the Senate and the House of...
# 1  When it was first perceived, in early times, t...
# 2  FRIENDS AND FELLOW-CITIZENS, Called upon to un...
# 3  Unwilling to depart from examples of the most ...
# 4  I should be destitute of feeling if I was not ...

# %%
speeches = pd.read_csv('data/presidential_speeches.csv')

# %%
speeches.head()
# Out:
#          Date          President         Party  \
# 0  1789-04-30  George Washington  Unaffiliated
# 1  1789-10-03  George Washington  Unaffiliated
# 2  1790-01-08  George Washington  Unaffiliated
# 3  1790-12-08  George Washington  Unaffiliated
# 4  1790-12-29  George Washington  Unaffiliated
#
#                                         Speech Title  \
# 0                            First Inaugural Address
# 1                          Thanksgiving Proclamation
# 2                   First Annual Message to Congress
# 3                  Second Annual Message to Congress
# 4  Talk to the Chiefs and Counselors of the Senec...
#
#                                              Summary  \
# 0  Washington calls on Congress to avoid local an...
# 1  At the request of Congress, Washington establi...
# 2  In a wide ranging speech, President Washington...
# 3  Washington focuses on commerce in his second a...
# 4  The President reassures the Seneca Nation that...
#
#                                           Transcript  \
# 0  Fellow Citizens of the Senate and the House of...
# 1  Whereas it is the duty of all Nations to ackno...
# 2  Fellow Citizens of the Senate and House of Rep...
# 3  Fellow citizens of the Senate and House of Rep...
# 4  I the President of the United States, by my ow...
#
#                                                  URL
# 0  https://millercenter.org/the-presidency/presid...
# 1  https://millercenter.org/the-presidency/presid...
# 2  https://millercenter.org/the-presidency/presid...
# 3  https://millercenter.org/the-presidency/presid...
# 4  https://millercenter.org/the-presidency/presid...

# %% [markdown]
# Import text from R script

# %%
ob=open('data/obama1.txt','rU')
raw_o=ob.read()
tokenizer = nltk.RegexpTokenizer(r"\w+")
obama = tokenizer.tokenize(raw_o)
# Out:
# C:\ProgramData\Anaconda3\envs\data620_web\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: 'U' mode is deprecated
#   """Entry point for launching an IPython kernel.

# %%
wa=open('data/washington.txt','rU')
raw_wa=wa.read()
tokenizer = nltk.RegexpTokenizer(r"\w+")
washington = tokenizer.tokenize(raw_wa)
# Out:
# C:\ProgramData\Anaconda3\envs\data620_web\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: 'U' mode is deprecated
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Update the text, remove stop words, lower case

# %%
obama = [word.lower() for word in obama if word.isalpha()]
washington = [word.lower() for word in washington if word.isalpha()]

# %%
obama_str = str(obama)
word_tokens = word_tokenize(obama_str)
tokens_without_sw = [w for w in word_tokens if not w in stop_words]
#tokens_without_sw = []        
obama_filtered = ("").join(tokens_without_sw)
obama_filtered = obama_filtered.replace(' , ', '')
obama_filtered = obama_filtered.replace(" ''", "")
obama_filtered = obama_filtered.replace("''", "")

# %%
len(obama_filtered)
# Out:
# 1521076

# %%
len(obama_filtered)/2000
# Out:
# 760.538

# %% [markdown]
# For ease of segmenting, I divided the length of the text by 2000 to get the amount of segments (1,101,169/2000 = ~550 Segments)

# %%
obama1=[]
for i in range(760):
    obama1.append([obama_filtered[i*2000:(i+1)*2000], 'ob'])

# %%
washington = [word.lower() for word in washington if word.isalpha()]
washington_str = str(washington)
word_tokens = word_tokenize(washington_str)
tokens_without_sw = [w for w in word_tokens if not w in stop_words]
#tokens_without_sw = []        
washington_filtered = ("").join(tokens_without_sw)
washington_filtered = washington_filtered.replace(' , ', '')
washington_filtered = washington_filtered.replace(" ''", "")
washington_filtered = washington_filtered.replace("''", "")

# %%
#reagan_filtered

# %%
len(washington_filtered)/2000
# Out:
# 123.555

# %%
washington1=[]
for i in range(775):
    washington1.append([washington_filtered[i*2000:(i+1)*2000], 're'])

# %% [markdown]
# ## Feature Extraction
#
# Creating the list of 1000 most frequent words

# %%
wo = obama+washington
all_words = nltk.FreqDist(w.lower() for w in wo)
word_features = list(all_words)[:1000] #1000 most frequent words
wlist=[]
for i in range(0,1000,50):
    df=pd.DataFrame(word_features[i:(i+50)])
    df.columns=['50 words']
    wlist.append(df)   
pd.concat(wlist, axis=1)
# Out:
#    50 words    50 words   50 words    50 words     50 words        50 words  \
# 0       the        been       need      change      support        continue
# 1       and        just        why       peace       public          across
# 2        to         one        its  businesses          men            free
# 3        of        when      other        much       reform        millions
# 4      that       these         he       could    education           since
# 5         a       which       year        give         very          family
# 6        we          re        may      energy      history       community
# 7        in     because       many        same      working           house
# 8       our       about        his          ll        state        military
# 9       for        them      think        part       making            high
# 10       is         new        don   insurance      between         leaders
# 11        i          my     future         got         each           under
# 12       it        make        own        next         both            meet
# 13        s        your       only     against      workers       countries
# 14       be        here       care        down      forward         promise
# 15     this        time        war    children          act            bill
# 16     have        than   security        home        class             off
# 17      you        some       even         job    companies      washington
# 18     will       world        way      before         such           build
# 19      are     country       made       great       around           again
# 20       on    american     health     tonight        lives          common
# 21      not      states       good      system     progress           folks
# 22     with       every       most          go         iraq           stand
# 23       as        know       last         tax         best            less
# 24      can          no       well       power    important         college
# 25      but        work      today    citizens      already            able
# 26     they       years       help        plan         hope           clear
# 27      who      united        she       thank        small        economic
# 28       by          up   congress         day          did  responsibility
# 29    their       right    believe        keep  opportunity            does
# 30     more       would      first     without          god         whether
# 31   people         out       take        hard         upon       financial
# 32       or      should       into       while       always            live
# 33        t        must   together    business         life            kids
# 34     from   americans       back         put         look            laws
# 35       so  government        her     nations         true          troops
# 36      all        like        any        sure        means              al
# 37     what        want        had       young         past             set
# 38      has         how   families       women          pay           issue
# 39       us        jobs    through      things     laughter          office
# 40       an        also     better         law  afghanistan              am
# 41       do         get        too         say        human          within
# 42       ve        over       come       never        thing          chance
# 43       at         let  president       being       israel         percent
# 44  america          me      still      middle          lot           start
# 45      now        were        two        done          ago            lead
# 46    there      nation       long      rights    something            once
# 47       if       going      after       place  republicans             use
# 48      was       where        see        then      another        national
# 49    those     economy       said         end          few       everybody
#
#       50 words     50 words        50 words       50 words     50 words  \
# 0         idea          far           clean          story      general
# 1    democracy         full          higher           ways       afghan
# 2         ever       nearly           built     themselves         told
# 3          won        union            days           grow        equal
# 4       months        doesn           times          earth        alone
# 5        doing   understand           makes        parties       choice
# 6         away      decades        students         secure       coming
# 7    different         find            tell      sometimes         path
# 8        money        bring          spirit         market       during
# 9       create          man             old         passed         race
# 10      crisis     possible            stop    generations    thousands
# 11     deficit     interest            cost     commitment      company
# 12       sense       school            didn        weapons      courage
# 13     million      finally          enough        friends      process
# 14        face     violence            talk           half     industry
# 15  challenges         cuts         schools         senate        order
# 16       qaeda       debate            term          known      present
# 17       agree    political          policy         moment      poverty
# 18         yet            d           words           john     election
# 19     justice         debt            fair           call      science
# 20        seen     question           space     technology   confidence
# 21       might        force         willing          ahead  information
# 22      course      efforts           comes         budget     medicare
# 23    politics       growth            came            yes         feel
# 24   democrats      example         growing          fight         four
# 25     century  communities      republican        greater       credit
# 26         big       single         respect         taking        truth
# 27       child         move         instead       everyone       living
# 28     protect        faith      everything        dollars     problems
# 29         cut         lost          global        getting        taxes
# 30      effort       values         members          among        cause
# 31      strong       reason         success         invest        trade
# 32       shall        point  administration       coverage   principles
# 33       share          ask          happen         choose        based
# 34        vote        three          issues       spending       behind
# 35       costs         kind          fellow      recognize     building
# 36        fact        rules          worked  international   experience
# 37  prosperity         took         nothing         beyond      service
# 38   ourselves        speak          little          raise       pursue
# 39        love       region        strength        certain       longer
# 40  generation        party         dignity         called   innovation
# 41      afford      foreign           given        parents      require
# 42     freedom        bless            real           iran          led
# 43       ideas       action          allies         second       reduce
# 44        open         pass          number      difficult      private
# 45      others       forces          decade          whole            q
# 46     nuclear       matter         prevent      including        found
# 47   necessary        reach         problem           hold         week
# 48         oil          him           taken          begin      deserve
# 49  leadership      provide       interests          often   democratic
#
#         50 words     50 words         50 words     50 words          50 words  \
# 0           fear       helped            haven      towards            social
# 1          works     recovery           places   ultimately          tomorrow
# 2          steps        north       bipartisan        court            rather
# 3        looking       having         whatever         rest           defense
# 4          needs         five       individual      reforms              stay
# 5        program        tough        recession    situation         challenge
# 6          offer  investments          student        ought           largest
# 7       benefits        dream       investment       dreams           attacks
# 8        society        white           abroad     teachers              case
# 9           goal           mr          purpose       harder            belief
# 10           gas     approach            heard        third             terms
# 11          save     somebody             wall         duty            income
# 12          seek        woman           remain         east              play
# 13        street        south            spend        close         influence
# 14        trying         side      governments   affordable             lower
# 15  constitution       fought          markets      mission               bin
# 16          else         turn     palestinians   immigrants             laden
# 17           six    resources  representatives      subject             weeks
# 18       liberty         easy           become     capacity          campaign
# 19      research        grace              gun      control           thought
# 20          hear        trust           expect      borders             worst
# 21       created   transition           answer       saying          commerce
# 22         serve       simply           itself     happened              sign
# 23          lose     conflict          ability     increase              none
# 24         along       ground           safety        asked           actions
# 25           isn        civil         pakistan        parts          trillion
# 26         basic       paying         israelis       europe              aren
# 27         until       entire            cuban        takes     comprehensive
# 28         leave      address          achieve         mind          training
# 29          send         cuba            doubt       result         agreement
# 30          safe         sick              saw   retirement         attention
# 31          line     remember             risk   difference            powers
# 32          self      federal             laid      measure     manufacturing
# 33        though     programs      differences        local        inequality
# 34       further          bad        questions  responsible             china
# 35           nor        whose             wars       giving           brought
# 36          step    decisions             deal       served  responsibilities
# 37       helping       simple         majority        wages               lay
# 38           top    beginning      individuals        spent           threats
# 39         focus        allow          several     greatest          strategy
# 40        ensure        least            rates         sent            ideals
# 41      actually         used           treaty        began            threat
# 42          mean   particular         measures         task           improve
# 43          paid   especially          talking     colleges             banks
# 44       serious         land         deficits    authority     circumstances
# 45           try        month             west  development       palestinian
# 46          hand        solve             left        proud          requires
# 47    strengthen         wage             join        homes            africa
# 48      stronger       person            gives     veterans           changes
# 49         honor  immigration              met        hands            skills
#
#          50 words       50 words      50 words       50 words
# 0        ordinary         anyone        mutual        minimum
# 1          really      neighbors        follow       grateful
# 2   opportunities       powerful       choices      sacrifice
# 3          defend  determination      believed        streets
# 4      throughout           held      governor          ready
# 5         muslims         expand         heart           knew
# 6          muslim           role         later        someone
# 7       essential          areas         knows           ours
# 8         chamber            buy       promote        natural
# 9       potential         either          fail        knowing
# 10           hire        succeed    foundation        hopeful
# 11         access   institutions        father         rising
# 12         combat        meeting         wrong         needed
# 13   particularly          assad         shape         effect
# 14       proposal        journey     secretary        changed
# 15         proper         shared  unemployment       consider
# 16         accept           went     executive        depends
# 17       starting         easier     committed         source
# 18           fall          wants        hearts       religion
# 19      standards        restore       however            hit
# 20     industries      character          rate       officers
# 21     terrorists        message     provision  entrepreneurs
# 22        climate        perfect    additional         depend
# 23            run           earn          city        perhaps
# 24          voice        remains          eyes          large
# 25        savings       fighting      hundreds        seniors
# 26            age         denied        earned  extraordinary
# 27      happiness        special           win         almost
# 28           rule         moving          says          lands
# 29           soon      encourage        mother   construction
# 30          globe         asking     diplomacy         nature
# 31         danger         burden        demand        conduct
# 32        elected           acts   accountable           nasa
# 33        lasting    competition         break      execution
# 34         agenda        session          arms        militia
# 35          facts         regime         aside          train
# 36           gave       products        former           news
# 37       peaceful      therefore        return         mccain
# 38         killed        indians      applause          chief
# 39        shouldn          night       medical       standing
# 40         friend          bills         level      providing
# 41         thanks         broken   legislation        learned
# 42           cars       policies         learn      terrorist
# 43       anything        senator         maybe           walk
# 44           ones           born       resolve       decision
# 45            fix        receive      proposed         voices
# 46        compete          loans           add       struggle
# 47       premiums           road       allowed    cooperation
# 48          iraqi           code    friendship          judge
# 49        taliban        billion    protection          stake

# %% [markdown]
# From text book

# %%
def document_features(document): 
    document_words = set(document) 
    features = {}
    for word in word_features:
        features['contains({})'.format(word)] = (word in document_words)
    return features

# %% [markdown]
# run features on Washington's speeches

# %%
features = document_features(washington)
list(features.items())[10:30]
# Out:
# [('contains(is)', True),
#  ('contains(i)', True),
#  ('contains(it)', True),
#  ('contains(s)', True),
#  ('contains(be)', True),
#  ('contains(this)', True),
#  ('contains(have)', True),
#  ('contains(you)', True),
#  ('contains(will)', True),
#  ('contains(are)', True),
#  ('contains(on)', True),
#  ('contains(not)', True),
#  ('contains(with)', True),
#  ('contains(as)', True),
#  ('contains(can)', True),
#  ('contains(but)', True),
#  ('contains(they)', True),
#  ('contains(who)', True),
#  ('contains(by)', True),
#  ('contains(their)', True)]

# %% [markdown]
# ## Test/Train Dataset

# %%
speeches = obama1+washington1

# %%
import random
random.shuffle(speeches)
featuresets = [(document_features(d), c) for (d,c) in speeches]
len(featuresets)
# Out:
# 1535

# %%
train_set, test_set = featuresets[:1000], featuresets[1000:]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.9289719626168225

# %% [markdown]
# 92%, the concept works!
#
# Does it get better or worse if we focus on speakers all from the same general era?.

# %% [markdown]
# ### Adding Roosevelt

# %%
ro=open('data/roosevelt.txt','rU')
raw_r=ro.read()
tokens_r = nltk.word_tokenize(raw_r)
roosevelt = nltk.Text(tokens_r)
roosevelt = [word.lower() for word in roosevelt if word.isalpha()]
roosevelt_str = str(roosevelt)
word_tokens = word_tokenize(roosevelt_str)
tokens_without_sw = [w for w in word_tokens if not w in stop_words]
#tokens_without_sw = []        
roosevelt_filtered = (" ").join(tokens_without_sw)
roosevelt_filtered = roosevelt_filtered.replace(' , ', '')
roosevelt_filtered = roosevelt_filtered.replace(" ''", " ")

len(roosevelt_filtered)/2000
# Out:
# C:\ProgramData\Anaconda3\envs\data620_web\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: 'U' mode is deprecated
#   """Entry point for launching an IPython kernel.
# 365.966

# %%
roosevelt1=[]
for i in range(365):
    roosevelt1.append([roosevelt_filtered[i*2000:(i+1)*2000], 'ro'])

# %%
ro = obama+roosevelt
all_words = nltk.FreqDist(w.lower() for w in ro)
word_features = list(all_words)[:200] #200 most frequent words

speeches = obama1+roosevelt1

# %%
random.shuffle(speeches)
featuresets = [(document_features(d), c) for (d,c) in speeches]
len(featuresets)
# Out:
# 1125

# %%
train_set, test_set = featuresets[:100], featuresets[100:]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.6721951219512196

# %% [raw]
# 67% not bad when focused on two presidents.  Not as good as the Washington/Obama model but still workable

# %% [markdown]
# ## Kennedy

# %%
ke=open('data/kennedy.txt','rU')
raw_k=ke.read()
tokens_k = nltk.word_tokenize(raw_k)
kennedy = nltk.Text(tokens_k)
kennedy = [word.lower() for word in kennedy if word.isalpha()]
kennedy_str = str(kennedy)
word_tokens = word_tokenize(kennedy_str)
tokens_without_sw = [w for w in word_tokens if not w in stop_words]
#tokens_without_sw = []        
kennedy_filtered = (" ").join(tokens_without_sw)
kennedy_filtered = kennedy_filtered.replace(' , ', '')
kennedy_filtered = kennedy_filtered.replace(" ''", " ")

len(kennedy_filtered)/2000
# Out:
# C:\ProgramData\Anaconda3\envs\data620_web\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: 'U' mode is deprecated
#   """Entry point for launching an IPython kernel.
# 336.1905

# %%
kennedy1=[]
for i in range(336):
    kennedy1.append([kennedy_filtered[i*2000:(i+1)*2000], 'ke'])

# %%
ork = obama+roosevelt+kennedy
all_words = nltk.FreqDist(w.lower() for w in ork)
word_features = list(all_words)[:200] #200 most frequent words

speeches = obama1+roosevelt1+kennedy1

# %%
random.shuffle(speeches)
featuresets = [(document_features(d), c) for (d,c) in speeches]
len(featuresets)
# Out:
# 1461

# %%
train_set, test_set = featuresets[:100], featuresets[100:]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.523879500367377

# %% [markdown]
# words words

# %% [markdown]
# ## Clinton

# %%
cl=open('data/clinton.txt','rU')
raw_c=cl.read()
tokens_c = nltk.word_tokenize(raw_c)
clinton = nltk.Text(tokens_c)
clinton = [word.lower() for word in clinton if word.isalpha()]
clinton_str = str(clinton)
word_tokens = word_tokenize(clinton_str)
tokens_without_sw = [w for w in word_tokens if not w in stop_words]
#tokens_without_sw = []        
clinton_filtered = (" ").join(tokens_without_sw)
clinton_filtered = clinton_filtered.replace(' , ', '')
clinton_filtered = clinton_filtered.replace(" ''", " ")

len(clinton_filtered)/2000
# Out:
# C:\ProgramData\Anaconda3\envs\data620_web\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: 'U' mode is deprecated
#   """Entry point for launching an IPython kernel.
# 367.9435

# %%
clinton1=[]
for i in range(367):
    clinton1.append([clinton_filtered[i*2000:(i+1)*2000], 'cl'])

# %%
orkc = obama+roosevelt+kennedy+clinton
all_words = nltk.FreqDist(w.lower() for w in orkc)
word_features = list(all_words)[:200] #200 most frequent words

speeches = obama1+roosevelt1+kennedy1+clinton1

# %%
random.shuffle(speeches)
featuresets = [(document_features(d), c) for (d,c) in speeches]
len(featuresets)
# Out:
# 1828

# %%
train_set, test_set = featuresets[:100], featuresets[100:]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.41550925925925924

# %% [markdown]
# words words

# %% [markdown]
# ## Reagan

# %%
re=open('data/reagan.txt','rU')
raw_re=re.read()
tokens_re = nltk.word_tokenize(raw_re)
reagan = nltk.Text(tokens_re)
reagan = [word.lower() for word in reagan if word.isalpha()]
reagan_str = str(reagan)
word_tokens = word_tokenize(reagan_str)
tokens_without_sw = [w for w in word_tokens if not w in stop_words]
#tokens_without_sw = []        
reagan_filtered = (" ").join(tokens_without_sw)
reagan_filtered = reagan_filtered.replace(' , ', '')
reagan_filtered = reagan_filtered.replace(" ''", " ")

len(reagan_filtered)/2000
# Out:
# C:\ProgramData\Anaconda3\envs\data620_web\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: 'U' mode is deprecated
#   """Entry point for launching an IPython kernel.
# 564.8405

# %%
reagan1=[]
for i in range(564):
    reagan1.append([reagan_filtered[i*2000:(i+1)*2000], 'cl'])

# %%
orkcr = obama+roosevelt+kennedy+clinton+reagan
all_words = nltk.FreqDist(w.lower() for w in orkcr)
word_features = list(all_words)[:200] #200 most frequent words

speeches = obama1+roosevelt1+kennedy1+clinton1+reagan1

# %%
random.shuffle(speeches)
featuresets = [(document_features(d), c) for (d,c) in speeches]
len(featuresets)
# Out:
# 2392

# %%
train_set, test_set = featuresets[:100], featuresets[100:]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.387434554973822

# %% [markdown]
# 38% proves our initial concern.  Since we are basing this research on speeches of people all from near the same era, it can be extremely difficult to teach a model to predict as more and more text gets added.
